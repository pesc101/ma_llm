# %% [markdown]
# ## Syntax Understanding

# %%
import pandas as pd
import json
from pathlib import Path
import os

# %%
root_folder = ""
df = pd.read_csv(f"{root_folder}/evaluation/data/syntax_qa_final.csv")

syntax_df = df.groupby("user_id").filter(lambda x: len(x) > 5)
syntax_df = syntax_df[
    (syntax_df["question_rating"] > 5) & (syntax_df["answer_rating"] > 5)
]
syntax_df["type"] = "syntax"

average_question_rating = syntax_df.groupby("user_id")["question_rating"].mean()
average_answer_rating = syntax_df.groupby("user_id")["answer_rating"].mean()
syntax_df = syntax_df[["question", "answer", "type", "module", "file_name", "start_line", "end_line"]]
syntax_df = syntax_df.reset_index()
syntax_df = syntax_df.drop(columns=["index"])

# %% [markdown]
# #### User Stats

# %%
filtered_df = df.groupby("user_id").filter(lambda x: len(x) > 5)
filtered_df["created"] = pd.to_datetime(filtered_df["created"])
time_diff_per_user = filtered_df.groupby("user_id")["created"].agg(lambda x: x.max() - x.min())

min_duration = time_diff_per_user.min()
mean_duration = time_diff_per_user.median()
std_duration = time_diff_per_user.std()
max_duration = time_diff_per_user.max()

min_duration, mean_duration, std_duration, max_duration
# Out:
# (Timedelta('0 days 00:38:58.042692'),
#  Timedelta('0 days 01:21:42.323134'),
#  Timedelta('0 days 02:43:36.669400473'),
#  Timedelta('0 days 08:18:05.677610'))

# %%
df = pd.read_csv(
    f"{root_folder}/evaluation/data/syntax_user_data_final.csv"
)
finished_users = df[df["status"] == "finished"]

mean_coding_knowledge = finished_users["coding_knowledge"].mean()
mean_python_knowledge = finished_users["python_knowledge"].mean()
mean_working_experience = finished_users["working_experience"].mean()

mean_coding_knowledge, mean_python_knowledge, mean_working_experience
# Out:
# (3.888888888888889, 4.333333333333333, 3.5555555555555554)

# %% [markdown]
# ## Dependency Understanding

# %%
depend_df = pd.read_json(f"{root_folder}/evaluation/data/dependency_spyder_qa.jsonl", lines=True)
depend_df["module"] = depend_df["target_file"].apply(lambda x: os.path.dirname(x))
depend_df["module"] = depend_df["module"].apply(lambda x: x.replace("/", "."))
depend_df["file_name"] = depend_df["target_file"].apply(lambda x: x.split("/")[-1])
depend_df["type"] = "dependencies"
depend_df["marked"] = "unmarked"
depend_df["start_line"] = None
depend_df["end_line"] = None
depend_df = depend_df[["marked", "question", "answer", "type", "module", "file_name", "start_line", "end_line"]]

depend_df = depend_df[depend_df["question"] != "What files are imported directly in the file test_profiler.py within the programming repository?"]
depend_df['question'] = depend_df['question'].str.replace('target file', 'file', case=False)
depend_df['answer'] = depend_df['answer'].str.replace('target file', 'file', case=False)

depend_df = depend_df.reset_index()
depend_df = depend_df.drop(columns=["index"])

# depend_df.to_csv(f"{root_folder}/evaluation/data/dependency_spyder_qa_unmarked.csv", index=False)

# %% [markdown]
# ### After Marked

# %%
depend_df = pd.read_csv("ma_llm/evaluation/data/dependency_spyder_qa_good.csv", sep=";")
depend_df = depend_df[depend_df.columns[1:8]]
depend_df["module"] = depend_df["module"].astype(str)
for index, row in depend_df.iterrows():
    if row["module"] == "nan":
        depend_df.at[index, 'module'] = "spyder"
    else:
        depend_df.at[index, 'module'] = "spyder." + row["module"]
depend_df = depend_df[~depend_df['file_name'].isna()]
depend_df
# Out:
#                                               question  \
# 0    Which libraries are used in the file spyder/ap...
# 1    What library is imported in the file 'spyder/p...
# 2    Which file does spyder.plugins.history.api.py ...
# 3    What library is directly imported in the file ...
# 4    What libraries are imported directly in the fi...
# ..                                                 ...
# 134  Does the file JsonRequestBehaviorObsedian cont...
# 135  Is the function to_text_string contained in th...
# 137  What libraries are directly imported in the fi...
# 138  What library is directly imported in the file ...
# 139  What libraries were directly imported in the f...
#
#                                                 answer          type  \
# 0    The libraries used in the file spyder/app/util...  dependencies
# 1    The library 'qtpy.QtCore' is imported in the f...  dependencies
# 2    It imports classes from spyder.plugins.history...  dependencies
# 3    The 'spyder/utils/snippets/ast.py' file direct...  dependencies
# 4    The file pycodestyle_conf.py directly imports ...  dependencies
# ..                                                 ...           ...
# 134                                                 No  dependencies
# 135                                                Yes  dependencies
# 137  functools, copy, typing, uuid, qtpy.QtCore, qt...  dependencies
# 138                                            logging  dependencies
# 139                  This information is not provided.  dependencies
#
#                                                 module            file_name  \
# 0                                    spyder.spyder.app             utils.py
# 1                      spyder.spyder.plugins.statusbar            plugin.py
# 2                        spyder.spyder.plugins.history               api.py
# 3                         spyder.spyder.utils.snippets               ast.py
# 4    spyder.external-deps.python-lsp-server.pylsp.c...  pycodestyle_conf.py
# ..                                                 ...                  ...
# 134                          spyder.spyder.api.widgets            mixins.py
# 135       spyder.spyder.plugins.explorer.widgets.tests          conftest.py
# 137                          spyder.spyder.plugins.run          confpage.py
# 138                   spyder.spyder.plugins.editor.api             panel.py
# 139  spyder.spyder.plugins.editor.widgets.codeedito...  test_breakpoints.py
#
#      start_line  end_line
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# ..          ...       ...
# 134         NaN       NaN
# 135         NaN       NaN
# 137         NaN       NaN
# 138         NaN       NaN
# 139         NaN       NaN
#
# [135 rows x 7 columns]

# %% [markdown]
# ## Meta Information Understanding

# %%
meta_df = pd.read_csv(f"{root_folder}/evaluation/data/meta_info_modified.csv", sep=";")
meta_df
# Out:
#                                              question  \
# 0        In which language is the repository written?
# 1       What are the main features of the Spyder IDE?
# 2   What is the recommended way to install the Spy...
# 3   What are other methods besides anaconda to ins...
# 4   What can happen without using Anaconda or Cond...
# 5     What are the main components of the Spyder IDE?
# 6   Where can I find the documentation of the Spyd...
# 7    What are the dependencies to install Spyder IDE?
# 8              What is the LICENCE of the Spyder IDE?
# 9   What are the guidelines for creating issues fo...
# 10  What are the steps to set up a development env...
# 11  What includes the contributor covenant code of...
# 12  How do members, contributors, and leaders pled...
# 13  What are the enforcement responsibilities outl...
# 14  What rights and responsibilities do community ...
# 15  Who supports the development of Spyder, the sc...
# 16  What is one way to make a financial contributi...
# 17  What are the basic dependencies required to ru...
# 18  What version of Python is required to run Spyder?
# 19                  What is PyQt5 used for in Spyder?
# 20  Why is installing Spyder via Anaconda recommen...
# 21    What are other installation options for Spyder?
# 22  How should reviewers communicate with contribu...
# 23  What approach should reviewers take when provi...
# 24  What should reviewers do if they and the autho...
# 25  How should reviews that address specific quest...
# 26  What questions should be considered regarding ...
# 27  What are the expected areas to be covered in t...
# 28  What steps must I follow to release a new vers...
# 29  What steps are involved in releasing a new ver...
# 30  What steps are involved in updating core depen...
# 31  How can you determine if a new version of spyd...
# 32  What files need to be updated to specify new p...
# 33  What is the first step to be taken after relea...
# 34            What does conda have to do with spyder?
# 35        What is the primary logo option for Spyder?
# 36  When is it preferable to use the primary logo ...
# 37  What colors are used in the full color options...
# 38  What is the minimum size for the primary Spyde...
# 39  What should be ensured when using the Spyder l...
# 40                         What is Python LSP Server?
# 41  What is the purpose of the Spyder Kernels pack...
# 42   How can Spyder Kernels be installed using conda?
# 43  What are the dependencies of the Spyder Kernel...
# 44                         What is Jupyter QtConsole?
# 45                    How can QtConsole be installed?
# 46  Who are the main contributors to the Spyder Pr...
# 47   From which sources were assets and code origi...
# 48  Where can more information about the sources a...
# 49  What are the steps to set up a development env...
#
#                                                answer  type  \
# 0   The repository is written in the Python progra...  meta
# 1   It combines the functionality of a comprehensi...  meta
# 2   The easiest way to install Spyder on any of ou...  meta
# 3   Unlock Python's full potential by choosing fro...  meta
# 4   We cannot offer personalised assistance to use...  meta
# 5   The software has five main components:\n1. Edi...  meta
# 6   If you want detailed information about Spyder,...  meta
# 7   Spyder's dependencies come pre-installed with ...  meta
# 8   MIT License Copyright (c) 2009- Spyder Project...  meta
# 9   When submitting an issue report for Spyder, pr...  meta
# 10  To set up a development environment for Spyder...  meta
# 11  Examples of good behavior:\n- Being respectful...  meta
# 12  They pledge to act and interact in ways that c...  meta
# 13  Community leaders are responsible for clarifyi...  meta
# 14  Community leaders have the right and responsib...  meta
# 15  Spyder development is supported by contributio...  meta
# 16  One way to make a donation to help fund furthe...  meta
# 17  The basic dependencies to run Spyder include P...  meta
# 18  Spyder requires Python 3.8 or higher as its co...  meta
# 19  PyQt5, which is Python bindings for Qt, is use...  meta
# 20   Installing Spyder via Anaconda is recommended...  meta
# 21  Other installation options for Spyder include ...  meta
# 22  Reviewers should begin with a positive comment...  meta
# 23   Reviewers should consider focusing on the mos...  meta
# 24   If after discussion, an author and a reviewer...  meta
# 25  Reviews that address specific questions on a P...  meta
# 26  Questions regarding the motivation behind a co...  meta
# 27  The expected areas to be covered in the code-f...  meta
# 28  1. Update translation strings at least one wee...  meta
# 29  The steps involved in releasing a new version ...  meta
# 30  The steps involved include reviewing the relea...  meta
# 31   Review the release notes of these packages to...  meta
# 32  The setup.py file (install_requires variable),...  meta
# 33  The first step is to publish the release on th...  meta
# 34  The Spyder installer uses conda packages to bu...  meta
# 35  The primary logo option for Spyder is the hori...  meta
# 36   It is preferable to use the primary logo that...  meta
# 37  The full color options of the Spyder logo are ...  meta
# 38   The minimum size for the primary Spyder logo ...  meta
# 39  When using the Spyder logo, ensure proportiona...  meta
# 40  Python LSP Server is a Python 3.8+ implementat...  meta
# 41  The Spyder Kernels package provides Jupyter ke...  meta
# 42  Spyder Kernels can be installed using conda wi...  meta
# 43  The Spyder Kernels package depends on ipykerne...  meta
# 44  Jupyter QtConsole is a rich Qt-based console f...  meta
# 45  QtConsole can be installed using conda with th...  meta
# 46  The main contributors to the Spyder Project ar...  meta
# 47   Assets and code for the Spyder Project were o...  meta
# 48   More information about the sources and author...  meta
# 49  To set up a development environment for QTCons...  meta
#
#                                     module                  file_name  \
# 0                                   spyder                  README.md
# 1                                   spyder                  README.md
# 2                                   spyder                  README.md
# 3                                   spyder                  README.md
# 4                                   spyder                  README.md
# 5                                   spyder                  README.md
# 6                                   spyder                  README.md
# 7                                   spyder                  README.md
# 8                                   spyder                LICENCE.txt
# 9                                   spyder            CONTRIBUTING.md
# 10                                  spyder            CONTRIBUTING.md
# 11                                  spyder         CODE_OF_CONDUCT.md
# 12                                  spyder         CODE_OF_CONDUCT.md
# 13                                  spyder         CODE_OF_CONDUCT.md
# 14                                  spyder         CODE_OF_CONDUCT.md
# 15                                  spyder                  README.md
# 16                                  spyder                  README.md
# 17                                  spyder                  README.md
# 18                                  spyder                  README.md
# 19                                  spyder                  README.md
# 20                                  spyder                  README.md
# 21                                  spyder                  README.md
# 22                                  spyder                  REVIEW.md
# 23                                  spyder                  REVIEW.md
# 24                                  spyder                  REVIEW.md
# 25                                  spyder                  REVIEW.md
# 26                                  spyder                  REVIEW.md
# 27                                  spyder                  REVIEW.md
# 28                                  spyder                 RELEASE.md
# 29                                  spyder                 RELEASE.md
# 30                                  spyder                 RELEASE.md
# 31                                  spyder                 RELEASE.md
# 32                                  spyder                 RELEASE.md
# 33                                  spyder                 RELEASE.md
# 34       spyder.installers-conda.resources           bundle_readme.md
# 35                    spyder.branding.logo  spyder-logo-guidelines.md
# 36                    spyder.branding.logo  spyder-logo-guidelines.md
# 37                    spyder.branding.logo  spyder-logo-guidelines.md
# 38                    spyder.branding.logo  spyder-logo-guidelines.md
# 39                    spyder.branding.logo  spyder-logo-guidelines.md
# 40  spyder.external-deps.python-lsp-server                  README.md
# 41  spyder.external-deps.python-lsp-server                  README.md
# 42     spyder.external-deps.spyder-kernels                  README.md
# 43     spyder.external-deps.spyder-kernels                  README.md
# 44          spyder.external-deps.qtconsole                  README.md
# 45          spyder.external-deps.qtconsole                  README.md
# 46                                  spyder                AUTHORS.txt
# 47                                  spyder                AUTHORS.txt
# 48                                  spyder                AUTHORS.txt
# 49          spyder.external-deps.qtconsole            CONTRIBUTING.md
#
#     start_line  end_line
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# 5          NaN       NaN
# 6          NaN       NaN
# 7          NaN       NaN
# 8          NaN       NaN
# 9          NaN       NaN
# 10         NaN       NaN
# 11         NaN       NaN
# 12         NaN       NaN
# 13         NaN       NaN
# 14         NaN       NaN
# 15         NaN       NaN
# 16         NaN       NaN
# 17         NaN       NaN
# 18         NaN       NaN
# 19         NaN       NaN
# 20         NaN       NaN
# 21         NaN       NaN
# 22         NaN       NaN
# 23         NaN       NaN
# 24         NaN       NaN
# 25         NaN       NaN
# 26         NaN       NaN
# 27         NaN       NaN
# 28         NaN       NaN
# 29         NaN       NaN
# 30         NaN       NaN
# 31         NaN       NaN
# 32         NaN       NaN
# 33         NaN       NaN
# 34         NaN       NaN
# 35         NaN       NaN
# 36         NaN       NaN
# 37         NaN       NaN
# 38         NaN       NaN
# 39         NaN       NaN
# 40         NaN       NaN
# 41         NaN       NaN
# 42         NaN       NaN
# 43         NaN       NaN
# 44         NaN       NaN
# 45         NaN       NaN
# 46         NaN       NaN
# 47         NaN       NaN
# 48         NaN       NaN
# 49         NaN       NaN

# %% [markdown]
# ## Export Dataset

# %%
def format_output(df: pd.DataFrame):
    results_to_dump = []
    for _, row in df.iterrows():
        results_to_dump.append(
            {
                "meta_data": {
                    "file_name": row["file_name"],
                    "module": row["module"],
                    "start_line": row["start_line"],
                    "end_line": row["end_line"],
                },
                "question": row["question"],
                "answer": row["answer"],
                "type": row["type"],
            }
        )
    return results_to_dump


def dump_jsonlines(obj, filepath, **kwargs):
    path = Path(filepath)
    path.parent.mkdir(parents=True, exist_ok=True)

    with open(filepath, "wt", encoding="utf-8") as fout:
        for d in obj:
            line_d = json.dumps(d, ensure_ascii=False, **kwargs)
            fout.write("{}\n".format(line_d))


df_complete = pd.concat([syntax_df, depend_df, meta_df])
final_json = format_output(df_complete)


dump_jsonlines(final_json, f"{root_folder}/evaluation/data/final_eval_custom_meta.jsonl")
